# %%
# %matplotlib notebook
import numpy as np
import scipy
import pylab as plt

# %%
tabla_model=np.genfromtxt('dat.dat',comments='#')
tabla_model[np.isnan(tabla_model)==True]=0.
t=tabla_model[:,0]
RG=tabla_model[:,1]
N=tabla_model[:,2]
M=tabla_model[:,3]
rh=tabla_model[:,4]
rj=tabla_model[:,5]
MS=tabla_model[:,6]
E=tabla_model[:,7]
kappa=tabla_model[:,8]
S=tabla_model[:,9]
t_rh=tabla_model[:,10]
nc=tabla_model[:,11]
t_rh_1=tabla_model[:,12]
nc_1=tabla_model[:,13]
gamma=tabla_model[:,14]
lambdaa=tabla_model[:,15]
xi=tabla_model[:,16]
mu=tabla_model[:,17]
epsilon=tabla_model[:,18]

# %%
#plt.plot(t,N)
#plt.plot(t,M)
#plt.plot(t,rh)
#plt.plot(t,rj)
#plt.plot(t,t_rh)
plt.plot(M,rh)
plt.gca().set_xscale("log")
plt.gca().set_yscale("log")
# Out:
# <img src="data:image/png;base64,..." width="640">
